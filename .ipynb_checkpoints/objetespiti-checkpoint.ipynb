# %% [markdown]
# obje tespiti

# %%
from mediapipe import solutions #el tespiti için görsel işleme görevleri için
from mediapipe.framework.formats import landmark_pb2 #"landmark_pb2" formatı cinsinden verileri almak için
import numpy as np
import cv2
import matplotlib.pyplot as plt
import mediapipe as mp
from mediapipe.tasks import python
from mediapipe.tasks.python import vision
import wget

# %%
MARGIN=10 #metnin üst köşesinden elin sınırına olan mesafe
FONT_SIZE=1 #yazı tipi boyutu
FONT_THICKNESS=1 #yazı kalınlığı
HANDEDNESS_TEXT_COLOR=(88,205,54) #rgb formatında yeşil renk

# %%
# !wget -q https://storage.googleapis.com/mediapipe-tasks/hand_landmarker/hand_landmarker.task
# Out:
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.

# %%
base_options = python.BaseOptions(model_asset_path="hand_landmarker.task")
options=vision.HandLandmarkerOptions(base_options=base_options, num_hands=2)
detector=vision.HandLandmarker.create_from_options(options)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[15], line 3
#       1 base_options = python.BaseOptions(model_asset_path="hand_landmarker.task")
#       2 options=vision.HandLandmarkerOptions(base_options=base_options, num_hands=2)
# ----> 3 detector=vision.HandLandmarker.create_from_options(options)
#
# File ~\miniconda3\lib\site-packages\mediapipe\tasks\python\vision\hand_landmarker.py:364, in HandLandmarker.create_from_options(cls, options)
#     342   options.result_callback(
#     343       hand_landmarks_detection_result,
#     344       image,
#     345       timestamp.value // _MICRO_SECONDS_PER_MILLISECOND,
#     346   )
#     348 task_info = _TaskInfo(
#     349     task_graph=_TASK_GRAPH_NAME,
#     350     input_streams=[
#    (...)
#     362     task_options=options,
#     363 )
# --> 364 return cls(
#     365     task_info.generate_graph_config(
#     366         enable_flow_limiting=options.running_mode
#     367         == _RunningMode.LIVE_STREAM
#     368     ),
#     369     options.running_mode,
#     370     packets_callback if options.result_callback else None,
#     371 )
#
# File ~\miniconda3\lib\site-packages\mediapipe\tasks\python\vision\core\base_vision_task_api.py:70, in BaseVisionTaskApi.__init__(self, graph_config, running_mode, packet_callback)
#      65 elif packet_callback:
#      66   raise ValueError(
#      67       'The vision task is in image or video mode, a user-defined result '
#      68       'callback should not be provided.'
#      69   )
# ---> 70 self._runner = _TaskRunner.create(graph_config, packet_callback)
#      71 self._running_mode = running_mode
#
# RuntimeError: Unable to open file at C:\Users\90543\Desktop\görüntüisleme\image_processing\hand_landmarker.task

# %%
img=cv2.imread("data/el_ornek.jpg")
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.figure()
plt.imshow(img)

# %%
img.shape
# Out:
# (960, 640, 3)

# %%
image=mp.Image.create_from_file("data/el_ornek.jpg")
detection_result=detector.detect(image)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 2
#       1 image=mp.Image.create_from_file("data/el_ornek.jpg")
# ----> 2 detection_result=detector.detect(image)
#
# NameError: name 'detector' is not defined

# %%
image

# %%
detection_result
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 detection_result
#
# NameError: name 'detection_result' is not defined

# %%
def draw_landmarks_on_image(rgb_image, detection_result):
    hand_landmarks_list=detection_result. hand_landmarks #tespit edilen elin işaretlendirmelerini içerir
    handedness_list=detection_result.handedness #tespit edilen elin sağ ve sol olma durumu
    annotated_image= np.copy(rgb_image) #girdi görüntüsü kopyalanır

    #tespit edilen elleri işaretlemek için bir döngü oluşturulur
    for idx in range(len(hand_landmarks_list)):
        hand_landmarks=hand_landmarks_list[idx] #indeksi kullanarak el işaretlemelerini alır
        handedness=handedness_list[idx] #indeksi kullanarak hangi elin tespit edildiği

        hand_landmarks_proto=landmark_pb2.NormalizedLandmarkList() #"landmark_pb2" formatında bir liste oluşturur
        hand_landmarks_proto.landmark.extend([landmark_pb2.NormalizedLandmark(x=landmark.x, y=landmark.y, z=landmark.z) for landmark in hand_landmarks])
        solutions.drawing_utils.draw_landmarks( #el işaretlemeleri görüntü üzerine çizilir
            annotated_image,
            hand_landmarks_proto,
            solutions.hands.HAND_CONNECTIONS,
            solutions.drawing_styles.get_default_hand_landmarks_style(),
            solutions.drawing_styles.get_default_hand_connections_style()) 
        
        height, width, _=annotated_image.shape
        x_coordinates = [landmark.x for landmark in hand_landmarks]
        y_coordinates = [landmark.y for landmark in hand_landmarks]
        text_x=int(min(x_coordinates*width))
        text_y=int(min(y_coordinates*height))-MARGIN

        cv2.putText(annotated_image,f"{handedness[0].category_name}", (text_x,text_y), cv2.FONT_HERSHEY_DUPLEX, FONT_SIZE, HANDEDNESS_TEXT_COLOR, FONT_THICKNESS,cv2.LINE_AA)

    return annotated_image

# %%
image.numpy_view()
# Out:
# array([[[21, 24, 17],
#         [21, 24, 17],
#         [21, 24, 17],
#         ...,
#         [23, 24, 16],
#         [23, 24, 16],
#         [23, 24, 16]],
#
#        [[21, 24, 17],
#         [21, 24, 17],
#         [21, 24, 17],
#         ...,
#         [23, 24, 16],
#         [23, 24, 16],
#         [23, 24, 16]],
#
#        [[21, 24, 17],
#         [21, 24, 17],
#         [21, 24, 17],
#         ...,
#         [23, 24, 16],
#         [23, 24, 16],
#         [23, 24, 16]],
#
#        ...,
#
#        [[15, 16, 10],
#         [15, 16, 10],
#         [15, 16, 10],
#         ...,
#         [16, 16,  8],
#         [16, 16,  8],
#         [16, 16,  8]],
#
#        [[15, 16, 10],
#         [15, 16, 10],
#         [15, 16, 10],
#         ...,
#         [15, 15,  7],
#         [16, 16,  8],
#         [16, 16,  8]],
#
#        [[15, 16, 10],
#         [15, 16, 10],
#         [15, 16, 10],
#         ...,
#         [15, 15,  7],
#         [15, 15,  7],
#         [15, 15,  7]]], dtype=uint8)

# %%
annotated_image=draw_landmarks_on_image(image.numpy_view(), detection_result)
plt.figure()
plt.imshow(annotated_image)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 annotated_image=draw_landmarks_on_image(image.numpy_view(), detection_result)
#       2 plt.figure()
#       3 plt.imshow(annotated_image)
#
# NameError: name 'detection_result' is not defined

# %%
img=cv2.imread("data/el_ornek2.jpg")
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.figure()
plt.imshow(img)

# %%
image=mp.Image.create_from_file("data/el_ornek2.jpg")

detection_result= detector.detect(image)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 3
#       1 image=mp.Image.create_from_file("data/el_ornek2.jpg")
# ----> 3 detection_result= detector.detect(image)
#
# NameError: name 'detector' is not defined

# %%
detection_result

# %%
annotated_image=draw_landmarks_on_image(image.numpy_view(), detection_result)
plt.figure()
plt.imshow(annotated_image)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 annotated_image=draw_landmarks_on_image(image.numpy_view(), detection_result)
#       2 plt.figure()
#       3 plt.imshow(annotated_image)
#
# NameError: name 'draw_landmarks_on_image' is not defined
